# %%
df_trips = spark. read. format("csv") \
.option("header","true") \
.option("inferSchema", "true") \
. load("/Volumes/taxi23catalog/texi_schema/taxi2volume/taxi_trip_data_raw.csv")

df_trips. show(5)

# %%
df_trips.write. format("delta"). saveAsTable("taxi23catalog.texi_schema. bronze_taxi_trips")

# %%
df_zones = spark. read. format("csv") \
.option("header","true") \
.option("inferSchema", "true") \
. load("/Volumes/taxi23catalog/texi_schema/taxi2volume/taxi_zone_lookup.csv")

df_zones. show(5)

# %%
df_zones.write. format("delta"). saveAsTable("taxi23catalog.texi_schema.bronze_taxi_zones")
